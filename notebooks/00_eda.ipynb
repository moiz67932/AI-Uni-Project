# %% [markdown]
# # 00 EDA
# This notebook imports the shared project code and runs the EDA phase.

# %%
from src.config import Config, ensure_project_dirs
from src.preprocessing import prepare_processed_data, run_eda

config = Config(base_dir='.')
ensure_project_dirs(config)
prepared = prepare_processed_data(config)
summary = run_eda(prepared['raw_df'], prepared['clean_df'], prepared['train_df'], prepared['val_df'], prepared['test_df'], prepared['train_opt'], prepared['val_opt'], prepared['test_opt'], config)
summary
