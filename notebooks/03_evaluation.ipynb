# %% [markdown]
# # 03 Evaluation
# This notebook loads saved outputs and reviews the final metrics.
#
# For Model A, use `positive_class_precision`, `positive_class_recall`, and `positive_class_f1` from the saved option-level metrics. Question-level accuracy is the main answer-selection metric.

# %%
from src.config import Config
from src.utils import load_json

config = Config(base_dir='.')
eda = load_json(config.EDA_SUMMARY_FILE, {})
model_a = load_json(config.MODEL_A_RESULTS_FILE, {})
model_b = load_json(config.MODEL_B_RESULTS_FILE, {})
final_metrics = load_json(config.FINAL_METRICS_FILE, {})
eda, model_a, model_b, final_metrics
